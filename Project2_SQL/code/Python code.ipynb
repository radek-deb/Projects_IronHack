# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

url = 'https://en.wikipedia.org/wiki/Kyoto_Protocol'

html = requests.get(url).content
soup = BeautifulSoup(html, "lxml")
table = soup.find_all('table',{'class':'wikitable'})[0]
table
rows = table.find_all('tr')
rows = [row.text.strip().split("\n") for row in rows]
rows
colnames = rows[0]
data = rows[1:]

df = pd.DataFrame(data, columns=colnames)
df
# Out:
#                            Country Kyototarget2008–2012[10]  \
# 0                        Australia                       +8
# 1                          Austria                      −13
# 2                          Belgium                       −8
# 3                         Bulgaria                       −8
# 4                Canada (withdrew)                       −6
# 5                          Croatia                       −5
# 6                   Czech Republic                       −8
# 7                          Denmark                      −21
# 8                          Estonia                       −8
# 9                          Finland                        0
# 10                          France                        0
# 11                         Germany                      −21
# 12                          Greece                      +25
# 13                         Hungary                       −6
# 14                         Iceland                      +10
# 15                         Ireland                      +13
# 16                           Italy                       −6
# 17                           Japan                       −6
# 18                          Latvia                       −8
# 19                   Liechtenstein                       −8
# 20                       Lithuania                       −8
# 21                      Luxembourg                      −28
# 22                          Monaco                       −8
# 23                     Netherlands                       −6
# 24                     New Zealand                        0
# 25                          Norway                       +1
# 26                          Poland                       −6
# 27                        Portugal                      +27
# 28                         Romania                       −8
# 29                          Russia                        0
# 30                        Slovakia                       −8
# 31                        Slovenia                       −8
# 32                           Spain                      +15
# 33                          Sweden                       +4
# 34                     Switzerland                       −8
# 35                         Ukraine                        0
# 36                  United Kingdom                      −13
# 37  United States (did not ratify)                       −7
#
#    Kyototarget2013–2020[116] GHGemissions2008–2012includingLULUCF[10]  \
# 0                       −0.5                                     +3.2
# 1                        −20                                     +3.2
# 2                        −20                                    −13.9
# 3                        −20                                    −53.4
# 4                        N/A                                    +18.5
# 5                        −20                                    −10.8
# 6                        −20                                    −30.6
# 7                        −20                                    −17.3
# 8                        −20                                    −54.2
# 9                        −20                                     −5.5
# 10                       −20                                    −10.5
# 11                       −20                                    −24.3
# 12                       −20                                    +11.5
# 13                       −20                                    −43.7
# 14                       −20                                    +10.2
# 15                       −20                                    +11.0
# 16                       −20                                     −7.0
# 17                       N/A                                     −2.5
# 18                       −20                                    −61.2
# 19                       −16                                     +4.1
# 20                       −20                                    −57.9
# 21                       −20                                     −9.3
# 22                       −22                                    −12.5
# 23                       −20                                     −6.2
# 24                       N/A                                     −2.7
# 25                       −16                                     +4.6
# 26                       −20                                    −29.7
# 27                       −20                                     +5.5
# 28                       −20                                    −57.0
# 29                       N/A                                    −36.3
# 30                       −20                                    −37.2
# 31                       −20                                     −9.7
# 32                       −20                                    +20.0
# 33                       −20                                    −18.2
# 34                     −15.8                                     −3.9
# 35                       −24                                    −57.1
# 36                       −20                                    −23.0
# 37                       N/A                                     +9.5
#
#    GHGemissions2008–2012excludingLULUCF[10]
# 0                                     +30.3
# 1                                      +4.9
# 2                                     −14.0
# 3                                     −52.8
# 4                                     +18.5
# 5                                      −7.5
# 6                                     −30.0
# 7                                     −14.8
# 8                                     −55.3
# 9                                      −4.7
# 10                                    −10.0
# 11                                    −23.6
# 12                                    +11.9
# 13                                    −41.8
# 14                                    +19.4
# 15                                     +5.1
# 16                                     −4.0
# 17                                     +1.4
# 18                                    −56.4
# 19                                     +2.4
# 20                                    −55.6
# 21                                     −8.7
# 22                                    −12.5
# 23                                     −6.4
# 24                                    +20.4
# 25                                     +7.5
# 26                                    −28.8
# 27                                    +22.4
# 28                                    −55.7
# 29                                    −32.7
# 30                                    −36.8
# 31                                     −3.2
# 32                                    +23.7
# 33                                    −15.3
# 34                                     −0.8
# 35                                    −56.6
# 36                                    −22.6
# 37                                     +9.5

# %%
df.to_excel('newfile.xlsx')
